# %%
print("Merhaba, İGÜ - YAPAY ZEKA") # print ekrana çıktı veren bir koddur.
# Out:
# Merhaba, İGÜ - YAPAY ZEKA

# %%
import sys # import python programlama dilinde yazılıma kütüphane eklemeye yarayan bir kod blogudur.
print(sys.version)
# Out:
# 3.10.12 (main, Sep 11 2024, 15:47:36) [GCC 11.4.0]

# %%
from google.colab import drive # google colab - drive bağlantısı

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

os.chdir('/content/drive/My Drive/YAPAYZEKA_ISTKA')

# !pwd # bize kodun çıktısını dosya yolu olarak veren kod blogudur.
# Out:
# /content/drive/My Drive/YAPAYZEKA_ISTKA

# %%
import pandas as pd
# Ayşe'nin ders ve not bilgileri
data = {'Ders': ['Algoritma', 'BilgisayarProgramlama', 'Elektronik-2', 'AviyonikSistemler'],
        'Not': [95, 100, 65, 90]}
# Veriyi bir DataFrame'e dönüştür
df = pd.DataFrame(data)
# En yüksek notu bul
en_yuksek_not = df['Not'].max()
print("En yüksek not:", en_yuksek_not)
# ortalama notu hesapla
ortalama_not = df['Not'].mean()
print("Ortalama not:", ortalama_not)
print(df.describe())
# Out:
# En yüksek not: 100
# Ortalama not: 87.5
#               Not
# count    4.000000
# mean    87.500000
# std     15.545632
# min     65.000000
# 25%     83.750000
# 50%     92.500000
# 75%     96.250000
# max    100.000000

# %%
import numpy as np

#Rastgele tanımlanan değerler - sıralaması olmayan
dizi = np.array([1, -55, 9, -23, 13, -21, 23, 37, 29, -6])

#Dizinin Ortalama Sonuc
ortalama = np.mean(dizi)
print("Ortalama:", ortalama)

#Dizinin Standart Sapma
std_sapma = np.std(dizi)
print("Standart Sapma:", std_sapma)

#Dizinin Mutlağını al
mutlak_veriler = np.abs(dizi)
print("Mutlak Deger Cıktısı:", mutlak_veriler)
# Out:
# Ortalama: 0.7
# Standart Sapma: 26.487921775783015
# Mutlak Deger Cıktısı: [ 1 55  9 23 13 21 23 37 29  6]

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 10, 100)
y = np.sin(x)

plt.plot(x, y)
plt.title('Sinüs Grafiği')
plt.xlabel('X Ekseni')
plt.ylabel('Y Ekseni')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

# Yıllara göre satışlar
yillar = [2018, 2019, 2020, 2021, 2022]
satislar = [150, 200, 20, -225, 14]

#Satış grafiğini çiz
plt.plot(yillar, satislar, marker='o')
#Grafik Başlıkları
plt.title("Yıllara Göre Satışlar")
plt.xlabel("Yıllar")
plt.ylabel("Satış Miktarı")
#Grafiği göster
plt.show()

# %%
import matplotlib.pyplot as plt

yillar = [2018, 2019, 2020, 2021, 2022]
satislar = [150, 200, 20, -225, 14]

plt.bar(yillar, satislar, color='skyblue')

plt.title("Yıllara Göre Satışlar")
plt.xlabel("Yıllar")
plt.ylabel("Satış Miktarı")

plt.show()

# %%
import matplotlib.pyplot as plt

yillar = [2018, 2019, 2020, 2021, 2022]
satislar = [150, 200, -120, -225, 14]

plt.barh(yillar, satislar, color='skyblue')

plt.title("Yıllara Göre Satışlar")
plt.xlabel("Satış Miktarı")
plt.ylabel("Yıllar")

plt.show()

# %%
yillar = [2018, 2019, 2020, 2021, 2022]
satislar = [150, 200, 20, -225, 14]

plt.scatter(yillar, satislar, color='pink')
plt.title("Yıllara Göre Satışlar")
plt.xlabel("Yıllar")
plt.ylabel("Satış Miktarı")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.random.rand(50)
y = np.random.rand(50)
colors = np.random.rand(50)
sizes = 1000 * np.random.rand(50)

plt.scatter(x, y, c=colors, s=sizes, alpha=0.5, cmap='viridis')
plt.title('Dağılım Grafiği')
plt.xlabel('X Ekseni')
plt.ylabel('Y Ekseni')
plt.colorbar()
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

x = np.linspace(-5, 5, 100)
y = np.linspace(-5, 10, 50)
X, Y = np.meshgrid(x, y)
Z = np.sin(np.sqrt(X**2 + Y**2))

ax.plot_surface(X, Y, Z, cmap='plasma')

ax.set_title('3D Yüzey Grafiği Örneği')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_colormaps():
    colormaps = plt.colormaps()
    n = len(colormaps)
    fig, axs = plt.subplots(n//2, 2, figsize=(10, 2*(n//2)))
    for ax, cmap_name in zip(axs.ravel(), colormaps):
        cmap = plt.get_cmap(cmap_name)
        img = np.linspace(0, 1, 256).reshape(1, -1)
        ax.imshow(img, aspect='auto', cmap=cmap)
        ax.set_title(cmap_name, fontsize=8)
        ax.set_axis_off()
    plt.show()

plot_colormaps()

# %%
import requests
from bs4 import BeautifulSoup
#Web sayfasının URL'sini al
url = 'https://www.mynet.com/'
#Web sayfasını indir
response = requests.get(url)
#Eğer bağlantı başarılıysa
if response.status_code == 200:
  #HTML içeriğini ayrıştır
    soup = BeautifulSoup(response.content, 'html.parser')
#Örnek olarak sayfadaki tüm başlıkları (h1,h2,h3 vb.) çek
    for heading in soup.find_all(['h1', 'h2', 'h3']):
        print(heading.text.strip())
else:
    print("Bağlantı başarısız: ", response.status_code)
# Out:
# SON DAKİKA HABERLERİ
# HAVA DURUMU
# 'Planlı olduğu belli' dedi! Bahçeli'yi hatırlattı
# 25 kilo verdikten sonra Cannes'a gitti! İşte tarzı
# Elfsborg hocası G.Saray'ı öve öve bitiremedi!
# İşte erişim sorununa ilişkin son durum!
# DİĞER MANŞETLER
# CANLI BORSA
# Kocasıyla boşandı! "Kiminle flörtleştiği..."
# Resmi Gazete'de yayımlandı: İlaca zam geldi! Fiyatlar değişiyor
# Başka kadınlar olduğu iddiası vardı! "Gizli kapaklı oldu" denilince...
# Kira fiyatları cep yakıyordu! Semt semt değerlendirdi!
# Stil sahibi kombinlere yaraşır bir ayakkabı: Camper Karst!
# Kaos var! "Nilüfer Hanım ne yaptı çocuğuma?"
# Blinken, terör saldırısını kınadı!
# Tüm çiftçileri unutun! Paraya para demiyor: "Güvensiz erkekler..."
# Eminönü-Bursa feribotunda panik anları! Bomba ihbarı yapıldı
# Özel'den terör saldırısı sonrası açıklama: 'Zamanlama dikkat çekici'
# Tepki çeken pozlar! Yemek yerken...
# Metrobüste yangın paniği!
# Hem tatil yapın hem kazanın! Keyif sürerken yatırım  da mümkün mü?
# ...

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://www.mynet.com/'

response = requests.get(url)

if response.status_code == 200:

    soup = BeautifulSoup(response.content, 'html.parser')

    links = soup.find_all('a')

    for link in links:
        href = link.get('href')
        text = link.text.strip()
        if href:
            print("Bağlantı metni: ", text, "URL:", href)
    print("Toplam bulunan bilgi sayısı: ", len(links), " adet")
else:
    print("Bağlantı başarısız: ", response.status_code)
# Out:
# Bağlantı metni:   URL: https://www.mynet.com
# Bağlantı metni:  HABER URL: https://www.mynet.com/haber
# Bağlantı metni:  SPOR URL: https://www.mynet.com/spor/
# Bağlantı metni:  FİNANS URL: https://finans.mynet.com
# Bağlantı metni:  MAGAZİN URL: https://www.mynet.com/magazin/
# Bağlantı metni:  OYUN URL: https://oyun.mynet.com
# Bağlantı metni:  EXPRESS URL: https://www.mynet.com/express
# Bağlantı metni:  VİTRİN URL: https://www.mynet.com/vitrin
# Bağlantı metni:  TÜMÜ URL: javascript:;
# Bağlantı metni:   URL: https://www.mynet.com/kadin
# Bağlantı metni:   URL: https://www.mynet.com/trend
# Bağlantı metni:   URL: https://www.mynet.com/yemek
# Bağlantı metni:   URL: https://www.mynet.com/vitrin
# Bağlantı metni:   URL: https://www.mynet.com/haberler/fintables
# Bağlantı metni:   URL: https://www.mynet.com/express
# Bağlantı metni:   URL: https://www.mynet.com/anket
# Bağlantı metni:   URL: https://www.mynet.com/aktuel
# ...

# %%
# !pip install opencv-python-headless

# %%
import os
import cv2
import matplotlib.pyplot as plt

# %%
klasor_yolu = '/content/drive/My Drive/YAPAYZEKA_ISTKA/Opencv_ornekleri'

# %%
resim_formatlari = ('.png', '.jpg', '.jpeg', '.bmp', '.gif', '.tiff')

# %%
islenen_bilgi = [f for f in os.listdir(klasor_yolu) if f.lower().endswith(resim_formatlari)]

print(f"Klasörde ", len(islenen_bilgi), "tane resim var.")

print("Resim dosyalarının isimleri ve dosya uzantıları")

for i in islenen_bilgi:
    print(i)
# Out:
# Klasörde  8 tane resim var.
# Resim dosyalarının isimleri ve dosya uzantıları
# python.png
# python2.png
# python3.png
# pythonopencvrenkli.png
# trafik-1.png
# trafik-2.png
# trafik-3.png
# Siberakademi.jpg

# %%
image = cv2.imread('Opencv_ornekleri/Siberakademi.jpg')

# %%
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.title("Yüklenen Görüntünün Gösterimi")
plt.show()

# %%
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

plt.imshow(gray_image, cmap='gray')
plt.title("Gri Tonlanmış Görüntü")
plt.show()

# %%
blurred_image = cv2.GaussianBlur(gray_image, (5, 5), 0)

plt.imshow(blurred_image, cmap='gray')
plt.title("Bulanıklaştırılmış Görüntü")
plt.show()

# %%
edges = cv2.Canny(blurred_image, threshold1=100, threshold2=200)

plt.imshow(edges, cmap='gray')
plt.title("Kenar Algılama Sonucu")
plt.show()

# %%
plt.figure(figsize=(10, 5))

plt.subplot(1, 4, 1)
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.title("Orijinal Görüntü")

plt.subplot(1, 4, 2)
plt.imshow(gray_image, cmap='gray')
plt.title("Gri Tonlama")

plt.subplot(1, 4, 3)
plt.imshow(blurred_image, cmap='gray')
plt.title("Bulanık Görüntü")

plt.subplot(1, 4, 4)
plt.imshow(edges, cmap='gray')
plt.title("Kenar Algılama")

plt.show()

# %%
#Görüntüleri yükleme
image1 = cv2.imread('Opencv_ornekleri/trafik-2.png')
image2 = cv2.imread('Opencv_ornekleri/trafik-3.png')
#Görüntüleri RGB formatına çevirme( OpenCV BGR formatında okur)
image1 = cv2.cvtColor(image1, cv2.COLOR_BGR2RGB)
image2 = cv2.cvtColor(image2, cv2.COLOR_BGR2RGB)

plt.subplot(1, 2, 1)
plt.imshow(image1)
plt.title('Görüntü 1')

plt.subplot(1, 2, 2)
plt.imshow(image2)
plt.title('Görüntü 2')

plt.show()

# %%
#Görüntüleri aynı boyuta getirme (boyutlar farklıysa)
image1_resized = cv2.resize(image1, (image2.shape[1], image2.shape[0]))

#Görüntüleri yan yana gösterme
plt.subplot(1, 2, 1)
plt.imshow(image1_resized)
height, width, channels = image1_resized.shape #1.görüntünün boyutunu bulma
plt.title('Yeniden Boyutlandırılan 1. Görsel')
print("1. Görüntü genişliği (x ekseni):", width, "piksel", "1. Görüntü yüksekliği (y ekseni):", height, "piksel")

plt.subplot(1, 2, 2)
plt.imshow(image2)
height2, width2, channels2 = image2.shape #2.görüntünün boyutunu bulma
plt.title('Yeniden Boyutlandırılan 2. Görsel')
print("2. Görüntü genişliği (x ekseni):", width2, "piksel", "2. Görüntü yüksekliği (y ekseni):", height2, "piksel")

plt.show()
# Out:
# 1. Görüntü genişliği (x ekseni): 527 piksel 1. Görüntü yüksekliği (y ekseni): 465 piksel
# 2. Görüntü genişliği (x ekseni): 527 piksel 2. Görüntü yüksekliği (y ekseni): 465 piksel

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

image1 = cv2.imread('Opencv_ornekleri/trafik-2.png')
image2 = cv2.imread('Opencv_ornekleri/trafik-3.png')

hsv_image1 = cv2.cvtColor(image1, cv2.COLOR_BGR2HSV)
hsv_image2 = cv2.cvtColor(image2, cv2.COLOR_BGR2HSV)

lower_red = np.array([0, 120, 70])
upper_red = np.array([10, 255, 255])

mask1_image1 = cv2.inRange(hsv_image1, lower_red, upper_red)
mask1_image2 = cv2.inRange(hsv_image2, lower_red, upper_red)

lower_red2 = np.array([170, 120, 70])
upper_red2 = np.array([180, 255, 255])

mask2_image1 = cv2.inRange(hsv_image1, lower_red2, upper_red2)
mask2_image2 = cv2.inRange(hsv_image2, lower_red2, upper_red2)

red_mask_image1 = mask1_image1 + mask2_image1
red_mask_image2 = mask1_image2 + mask2_image2

red_result_image1 = cv2.bitwise_and(image1, image1, mask=red_mask_image1)
red_result_image2 = cv2.bitwise_and(image2, image2, mask=red_mask_image2)

plt.subplot(1, 2, 1)
plt.imshow(cv2.cvtColor(red_result_image1, cv2.COLOR_BGR2RGB))
plt.title('Kırmızı Ok - Görüntü 1')

plt.subplot(1, 2, 2)
plt.imshow(cv2.cvtColor(red_result_image2, cv2.COLOR_BGR2RGB))
plt.title('Kırmızı Ok - Görüntü 2')

plt.show()

# %%
import cv2

img = cv2.imread('Opencv_ornekleri/trafik-1.png')

gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

ret, thresh_img = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)

print(f'Otsu ile bulunan eşik değeri: {ret}')
# Out:
# Otsu ile bulunan eşik değeri: 169.0

# %%
plt.subplot(1, 2, 1)
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.title('Orijinal Resim')
plt.axis('off')
# Out:
# (-0.5, 564.5, 423.5, -0.5)

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

ret, thresh_img = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)

plt.figure(figsize=(10,5))

plt.subplot(1, 2, 2)
plt.imshow(thresh_img, cmap='gray')
plt.title("Otsu çıktısı: {}".format(ret))
plt.axis('off')

plt.show()
